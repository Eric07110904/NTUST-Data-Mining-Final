# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
AQ_W = [[0.9969711384120412, 0.9999289241921504, 0.9999289241921504],
[0.7395740516319426, 0.7821324446866557, 0.8013885583013313],
[0.8101217804162035, 0.8887461892246478, 0.9141900295455648],
[0.8056174697476237, 0.8502883505686574, 0.8828367543418252],
[0.9725999705369002, 0.9786022116761692, 0.9791312266751793],
[0.9925597361061185, 0.9939890887952855, 0.9944356855370359]]
AQ_X = [[0.9969711384120412, 0.9996417169479381, 0.9999289241921504],
[0.7395740516319426, 0.825835847578314, 0.83668646778822],
[0.8101217804162035, 0.8949574315439359, 0.9211658065310909],
[0.8056174697476237, 0.8705382494972512, 0.8752217243372652],
[0.9725999705369002, 0.980999138114623, 0.9872882614116639],
[0.9925597361061185, 0.9939890887952855, 0.9984461644398684]]

Annthyroid_W = [[1.0, 1.0, 1.0],
[0.8354745401861351, 0.9130785938887429, 0.9540399564535456],
[0.9788332804758428, 0.9960381180407369, 0.998208817026864]]
Annthyroid_X = [[1.0, 1.0, 1.0],
[0.8354745401861351, 0.9176805368720728, 0.9281152494044433],
[0.9788332804758428, 0.9945962728278372, 0.998208817026864]]

Breastw_W = [[0.7557964320877607, 0.8005521818748657, 0.8627613265170042],
[0.779853713287082, 0.8364218231382952, 0.8612130845511615]]
Breastw_X = [[0.7557964320877607, 0.8391153368803516, 0.8726931450542526],
[0.779853713287082, 0.8324931602770231, 0.8550730509617048]]

Iris_W = [[0.8095363683076429, 0.876877413807096, 0.9316573462381269],
[0.9783662300482189, 1.0, 1.0]]
Iris_X = [[0.8095363683076429, 0.956571799153398, 0.9632012886643058],
[0.9783662300482189, 1.0, 1.0]]

mammograph_W = [[0.9979288098304272, 1.0, 1.0],
[0.9930348102325143, 0.9992642905239344, 0.9992642905239344],
[0.8180374886697928, 0.9215420702773576, 0.9416018249526992],
[0.9984580306257282, 0.9984580306257282, 0.9991720894919763]]
mammograph_X = [[0.9979288098304272, 1.0, 1.0],
[0.9930348102325143, 0.9957759424779313, 0.999894351744779],
[0.8180374886697928, 0.8900465022297718, 0.9086176129665666],
[0.9984580306257282, 0.9992859411337519, 1.0]]

pendigit_W = [[0.9194461465814429, 0.9463783420377502, 0.9496870896075134],
[0.9638569946777453, 0.9676041221560152, 0.9676041221560152],
[0.8336046406358111, 0.857196740189597, 0.9562478051763839],
[0.9646419987642766, 0.974456867939672, 0.9906528772006498],
[0.9616226974923788, 0.9757245522400845, 0.9757245522400845]]
pendigit_X = [[0.9194461465814429, 0.9463783420377502, 0.9614478049042215],
[0.9638569946777453, 0.976984396381544, 0.979568483863329],
[0.8113660861725042, 0.9599520798527422, 0.9600886074711916],
[0.9646419987642766, 0.9761777509992475, 0.9885031561452761],
[0.9616226974923788, 0.9837588170152916, 0.9837588170152916]]

# %%
AQ_X = np.array(AQ_X)
AQ_W = np.array(AQ_W)
Annthyroid_X = np.array(Annthyroid_X)
Annthyroid_W = np.array(Annthyroid_W)
Breastw_X = np.array(Breastw_X)
Breastw_W = np.array(Breastw_W)
Iris_X = np.array(Iris_X)
Iris_W = np.array(Iris_W)
mammograph_X = np.array(mammograph_X)
mammograph_W = np.array(mammograph_W)
pendigit_X = np.array(pendigit_X)
pendigit_W = np.array(pendigit_W)

# %%
dataset_sort = [AQ_W, Iris_W, Breastw_W, mammograph_W, Annthyroid_W, pendigit_W]
# dataset_sort = [AQ_X, Iris_X, Breastw_X, mammograph_X, Annthyroid_X, pendigit_X]

plt.figure(figsize=(10,5))#设置画布的尺寸
labels = ["AQ", "", "",
          "IR", "", "",
          "BR", "", "",
          "MA", "", "", 
          "AN", "", "", 
          "PE", "", "",]
show_list = []
for dataset in dataset_sort:
    for i in range(3):
        show_list.append(dataset[:,i])
plt.boxplot(show_list, labels=labels)
plt.ylim(0, 1)
plt.ylabel("Incrimination(%)") # y label
plt.xlabel("Datasets") # x label
plt.show()#显示图

# %%
AQ_W_1 = [[0.6310140149675488, 0.6332290505900942, 0.6758170238009696],
[0.7107021737417731, 0.7383136766307107, 0.7553696760160922],
[0.43707478718225123, 0.5066008693154478, 0.5351971730154552],
[0.7996934112648644, 0.8502883505686574, 0.8682349947012985],
[0.7179764004919705, 0.7251674271350652, 0.7671252619527985],
[0.7012238214180291, 0.7043366764566471, 0.7419532907417118]]

AQ_W_10 = [[0.9969711384120412, 0.9999289241921504, 0.9999289241921504],
[0.7395740516319426, 0.7821324446866557, 0.8013885583013313],
[0.8101217804162035, 0.8887461892246478, 0.9141900295455648],
[0.8056174697476237, 0.8502883505686574, 0.8828367543418252],
[0.9725999705369002, 0.9786022116761692, 0.9791312266751793],
[0.9925597361061185, 0.9939890887952855, 0.9944356855370359]]
AQ_W_1 = np.array(AQ_W_1)
AQ_W_10 = np.array(AQ_W_10)

# %%
y10 = np.array([1,  4,  7,  10,  13,   16])
y1 = np.array([2,  5,  8,  11,  14,  17])
plt.bar(y1 , AQ_W_1[:,1] , width=1, label="Global", color="orange")
plt.bar(y10, AQ_W_10[:,1], width=1, label="Local", color="blue")
plt.ylabel("Incrimination(%)") # y label
plt.xlabel("Clusters") # x label
plt.legend()
plt.xticks([1.5, 4.5, 7.5, 10.5, 13.5, 16.5], ["c1","c2","c3","c4","c5","c6"])
plt.show()

# %%
pendigit_W_10 = [[0.9194461465814429, 0.9463783420377502, 0.9496870896075134],
[0.9638569946777453, 0.9676041221560152, 0.9676041221560152],
[0.8336046406358111, 0.857196740189597, 0.9562478051763839],
[0.9646419987642766, 0.974456867939672, 0.9906528772006498],
[0.9616226974923788, 0.9757245522400845, 0.9757245522400845]]
pendigit_W_1 = [[0.8235860913116317, 0.9228489721886013, 0.949281189709067],
[0.9638569946777453, 0.9676041221560152, 0.9751937523420078],
[0.8336046406358111, 0.857196740189597, 0.8929155883596992],
[0.8626875730510614, 0.8626875730510614, 0.9405812215879978],
[0.9535404094949474, 0.9620474999761535, 0.9685528937462737]]
pendigit_W_1 = np.array(pendigit_W_1)
pendigit_W_10 = np.array(pendigit_W_10)
print(pendigit_W_1.shape, pendigit_W_10.shape)
# Out:
# (5, 3) (5, 3)

# %%
y10 = np.array([1,  4,  7,  10,  13])
y1 = np.array([2,  5,  8,  11,  14])
plt.bar(y1 , pendigit_W_1[:,1] , width=1, label="Global", color="orange")
plt.bar(y10, pendigit_W_10[:,1], width=1, label="Local", color="blue")
plt.ylabel("Incrimination(%)") # y label
plt.xlabel("Clusters") # x label
plt.legend()
plt.xticks([1.5, 4.5, 7.5, 10.5, 13.5, 16.5], ["c1","c2","c3","c4","c5","c6"])
plt.show()

# %%
# Out:
# array([0.92284897, 0.96760412, 0.85719674, 0.86268757, 0.9620475 ])
