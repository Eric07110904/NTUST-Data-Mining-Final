# %%
import sys 
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme()
from utils import *
from STSC.stsc import *

# %%
def load_npy(filepath: str) -> np.ndarray:
    return np.load(filepath)

# %%
AQ_W = load_npy('../weights/W/weight_airquality.npy')
Annthyroid_W = load_npy('../weights/W/weight_annthyroid.npy')
Breastw_W = load_npy('../weights/W/weight_breastw.npy')
Iris_W = load_npy('../weights/W/weight_iris.npy')
mammograph_W = load_npy('../weights/W/weight_mammograph.npy')
pendigit_W = load_npy('../weights/W/weight_pendigits.npy')

# %%
draw_boxplot([AQ_W, Iris_W, Breastw_W, mammograph_W, Annthyroid_W, pendigit_W])
